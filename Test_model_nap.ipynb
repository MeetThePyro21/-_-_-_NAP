# %%
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
import seaborn as sns
color = sns.color_palette()

from collections import Counter
from sklearn.metrics import classification_report

# %%
df = pd.read_csv('/Users/awesome/Downloads/предсказание_спроса/train.csv', sep=';')
df.head()
# Out:
#    label      period subject_type subject_name city_name              hex  \
# 0      1  2020-05-01        Город       Москва    Москва  8611aa7a7ffffff
# 1      1  2020-05-01        Город       Москва    Москва  8611aa01fffffff
# 2      1  2020-05-01        Город       Москва    Москва  861181b6fffffff
# 3      1  2020-05-01        Город       Москва    Москва  8611aa017ffffff
# 4      1  2020-05-01        Город       Москва    Москва  8611aa637ffffff
#
#      hex_lat    hex_lon       f1       f2  ...      f21  f22      f23  \
# 0  55.729458  37.516569  0.00101  0.00103  ...  0.13027  0.0  0.00000
# 1  55.975851  37.237085  0.00000  0.00027  ...  0.08756  0.0  0.00000
# 2  55.622721  37.695121  0.00339  0.00313  ...  0.09243  0.0  0.00000
# 3  55.941586  37.157487  0.00048  0.00054  ...  0.10192  0.0  0.00049
# 4  55.797494  37.676200  0.00164  0.00179  ...  0.09620  0.0  0.00000
#
#        f24      f25      f26      f27      f28      f29  f30
# 0      NaN      NaN      NaN      NaN      NaN  0.01737  0.0
# 1      NaN      NaN      NaN      NaN      NaN  0.01152  0.0
# 2  0.11053  0.57895  0.00526  0.02105  0.00000  0.01540  0.0
# 3      NaN      NaN      NaN      NaN      NaN  0.01495  0.0
# 4  0.14444  0.64444  0.01111  0.04444  0.01111  0.01266  0.0
#
# [5 rows x 38 columns]

# %%
df.subject_name.value_counts()
# Out:
# Москва             22606
# Санкт-Петербург    15876
# Краснодарский      11140
# Московская         10994
# Нижегородская      10371
#                    ...
# Алтай                208
# Тыва                 168
# Ингушетия            145
# Ненецкий             101
# Чукотский              2
# Name: subject_name, Length: 82, dtype: int64

# %%
df.city_name.value_counts()
# Out:
# Москва             22444
# Санкт-Петербург    13805
# Новосибирск         5018
# Нижний Новгород     4785
# Тольятти            3616
#                    ...
# Сретенское             1
# Усолье                 1
# Карандашово            1
# Трубный                1
# Сюля                   1
# Name: city_name, Length: 4633, dtype: int64

# %%
df.label.value_counts()
# Out:
# 0    287152
# 1      7106
# Name: label, dtype: int64

# %%
df.period = pd.to_datetime(df.period)

df['year'] = df.period.dt.year
df['month'] = df.period.dt.month
df['quarter_of_year'] = df.period.dt.quarter

df = df.drop(columns=['period'])

# %%
# df = df[['label', 'f12', 'f10', 'f3', 'f28', 'f11', 'subject_name',
#          'f15', 'f1', 'f20', 'f2', 'hex_lat', 'f21',
#          'f17', 'month', 'hex_lon', 'f6', 'f9', 'f24',
#          'f16', 'subject_type', 'quarter_of_year']]

# %%
from sklearn.preprocessing import LabelBinarizer

lb = LabelBinarizer()

df = df.join(pd.DataFrame(lb.fit_transform(df['subject_type']),
                                  columns=lb.classes_, 
                                  index=df.index))

df = df.join(pd.DataFrame(lb.fit_transform(df['subject_name']),
                                  columns=lb.classes_, 
                                  index=df.index))

df = df.drop(columns=['subject_name', 'subject_type', 'city_name', 'hex'])

# %%
# df = df.fillna(0)

# %%
X = df.drop("label", axis=1)
y = df["label"]

# %%
from numpy import hstack
from sklearn.model_selection import train_test_split

from catboost import CatBoostClassifier, Pool
from xgboost import XGBClassifier
import lightgbm as lgb

def get_models():
    models = []
    models.append(('lr', CatBoostClassifier(n_estimators=350)))
    models.append(('gbr', XGBClassifier(n_estimators=350)))
    models.append(('cbr', lgb.LGBMClassifier(n_estimators=350)))

    return models

# обучает ансамблевую модель с использованием обучающего 
# и независимого набора данных
def fit_ensemble(models, X_train, X_val, y_train, y_val):
    meta_X = list()
    for name, model in models:
        # обучение
        model.fit(X_train, y_train) 
        # предсказания для каждой модели
        reg = model.predict(X_val)
        # в матрицу с 1 колонкой
        reg = reg.reshape(len(reg), 1)
        # прогнозные значения храним в списке (потом сделаем массив)
        meta_X.append(reg)

    # создаем 2д массив
    meta_X = hstack(meta_X)
    # определяем нашу смешенную модель
    blender_model = lgb.LGBMClassifier(n_estimators=300)
    # обучение метамодели
    blender_model.fit(meta_X, y_val)

    return blender_model

# собрать прогнозы каждой базовой модели в обучающий набор данных,
# сложить прогнозы вместе и вызвать predict() в ансамблевой модели 
def predict_ensemble(models, blender_model, X_test):
    # предсказания с базовыми моделями
    meta_X = list()
    for name, model in models:
        # предсказание
        reg = model.predict(X_test)
        # в матрицу с 1 колонкой
        reg = reg.reshape(len(reg), 1)
        meta_X.append(reg)
    # создаем 2д массив из предсказаний
    meta_X = hstack(meta_X)
    # predict
    return blender_model.predict(meta_X)

# %%
X_train_full, X_test, y_train_full, y_test = train_test_split(X, y, 
                                                              test_size=0.15, random_state=1)

X_train, X_val, y_train, y_val = train_test_split(X_train_full, y_train_full,
                                                  test_size=0.15, random_state=1) 

# базовая модель
models = get_models()
# обучение
blender_model = fit_ensemble(models, X_train, X_val, y_train, y_val)
# тестирование
prediction = predict_ensemble(models, blender_model, X_test)
# метрики
# Out:
# Learning rate set to 0.266008
# 0:	learn: 0.3360742	total: 75.5ms	remaining: 26.4s
# 1:	learn: 0.1954634	total: 89.1ms	remaining: 15.5s
# 2:	learn: 0.1391451	total: 103ms	remaining: 11.9s
# 3:	learn: 0.1182406	total: 115ms	remaining: 9.96s
# 4:	learn: 0.1074505	total: 130ms	remaining: 8.99s
# 5:	learn: 0.1024538	total: 143ms	remaining: 8.21s
# 6:	learn: 0.0998201	total: 156ms	remaining: 7.66s
# 7:	learn: 0.0978217	total: 170ms	remaining: 7.26s
# 8:	learn: 0.0967349	total: 182ms	remaining: 6.91s
# 9:	learn: 0.0954369	total: 196ms	remaining: 6.65s
# 10:	learn: 0.0947610	total: 214ms	remaining: 6.58s
# 11:	learn: 0.0945001	total: 229ms	remaining: 6.44s
# 12:	learn: 0.0941279	total: 243ms	remaining: 6.3s
# 13:	learn: 0.0937801	total: 256ms	remaining: 6.14s
# 14:	learn: 0.0934691	total: 269ms	remaining: 6s
# 15:	learn: 0.0932856	total: 281ms	remaining: 5.88s
# 16:	learn: 0.0930851	total: 294ms	remaining: 5.76s
# 17:	learn: 0.0928733	total: 306ms	remaining: 5.65s
# 18:	learn: 0.0927504	total: 318ms	remaining: 5.54s
# 19:	learn: 0.0924481	total: 332ms	remaining: 5.48s
# 20:	learn: 0.0921873	total: 345ms	remaining: 5.4s
# 21:	learn: 0.0920007	total: 358ms	remaining: 5.33s
# 22:	learn: 0.0918709	total: 371ms	remaining: 5.27s
# 23:	learn: 0.0916255	total: 383ms	remaining: 5.2s
# 24:	learn: 0.0914611	total: 395ms	remaining: 5.14s
# 216:	learn: 0.0783005	total: 2.94s	remaining: 1.8s
# 217:	learn: 0.0782481	total: 2.95s	remaining: 1.79s
# 218:	learn: 0.0781995	total: 2.96s	remaining: 1.77s
# 219:	learn: 0.0781525	total: 2.98s	remaining: 1.76s
# 220:	learn: 0.0780766	total: 2.99s	remaining: 1.75s
# 221:	learn: 0.0780242	total: 3s	remaining: 1.73s
# 222:	learn: 0.0780004	total: 3.02s	remaining: 1.72s
# 223:	learn: 0.0779791	total: 3.03s	remaining: 1.7s
# 224:	learn: 0.0779352	total: 3.04s	remaining: 1.69s
# 225:	learn: 0.0778933	total: 3.05s	remaining: 1.68s
# 226:	learn: 0.0778241	total: 3.07s	remaining: 1.66s
# 227:	learn: 0.0777286	total: 3.08s	remaining: 1.65s
# 228:	learn: 0.0776819	total: 3.09s	remaining: 1.63s
# 229:	learn: 0.0776337	total: 3.11s	remaining: 1.62s
# 230:	learn: 0.0776004	total: 3.12s	remaining: 1.61s
# 231:	learn: 0.0774559	total: 3.13s	remaining: 1.59s
# 232:	learn: 0.0773685	total: 3.15s	remaining: 1.58s
# 233:	learn: 0.0773474	total: 3.16s	remaining: 1.56s
# 234:	learn: 0.0772888	total: 3.17s	remaining: 1.55s
# 235:	learn: 0.0772368	total: 3.18s	remaining: 1.54s
# 236:	learn: 0.0771870	total: 3.2s	remaining: 1.52s
# 237:	learn: 0.0771262	total: 3.21s	remaining: 1.51s
# 238:	learn: 0.0770833	total: 3.22s	remaining: 1.5s
# 239:	learn: 0.0770667	total: 3.23s	remaining: 1.48s
# 240:	learn: 0.0770181	total: 3.25s	remaining: 1.47s
# 241:	learn: 0.0769773	total: 3.26s	remaining: 1.45s
# 242:	learn: 0.0769166	total: 3.27s	remaining: 1.44s
# 243:	learn: 0.0768603	total: 3.28s	remaining: 1.43s
# 244:	learn: 0.0768142	total: 3.3s	remaining: 1.41s
# 245:	learn: 0.0767728	total: 3.31s	remaining: 1.4s
# 246:	learn: 0.0767266	total: 3.32s	remaining: 1.39s
# 247:	learn: 0.0766999	total: 3.34s	remaining: 1.37s
# 248:	learn: 0.0766418	total: 3.35s	remaining: 1.36s
# 249:	learn: 0.0765995	total: 3.36s	remaining: 1.34s
# 250:	learn: 0.0765413	total: 3.38s	remaining: 1.33s
# 251:	learn: 0.0764812	total: 3.39s	remaining: 1.32s
# 252:	learn: 0.0764201	total: 3.4s	remaining: 1.3s
# 253:	learn: 0.0764039	total: 3.41s	remaining: 1.29s
# 254:	learn: 0.0763849	total: 3.42s	remaining: 1.28s
# 255:	learn: 0.0763626	total: 3.44s	remaining: 1.26s
# 256:	learn: 0.0763129	total: 3.45s	remaining: 1.25s
# 257:	learn: 0.0762767	total: 3.46s	remaining: 1.24s
# 258:	learn: 0.0762089	total: 3.48s	remaining: 1.22s
# 259:	learn: 0.0761908	total: 3.49s	remaining: 1.21s
# 260:	learn: 0.0761427	total: 3.5s	remaining: 1.19s
# 261:	learn: 0.0760702	total: 3.51s	remaining: 1.18s
# 262:	learn: 0.0759948	total: 3.53s	remaining: 1.17s
# 312:	learn: 0.0736207	total: 4.17s	remaining: 493ms
# 313:	learn: 0.0735773	total: 4.18s	remaining: 480ms
# 314:	learn: 0.0735570	total: 4.2s	remaining: 466ms
# 315:	learn: 0.0735428	total: 4.21s	remaining: 453ms
# 316:	learn: 0.0734865	total: 4.22s	remaining: 440ms
# 317:	learn: 0.0734305	total: 4.23s	remaining: 426ms
# 318:	learn: 0.0733841	total: 4.25s	remaining: 413ms
# 319:	learn: 0.0733210	total: 4.26s	remaining: 399ms
# 320:	learn: 0.0733105	total: 4.27s	remaining: 386ms
# 321:	learn: 0.0732400	total: 4.29s	remaining: 373ms
# 322:	learn: 0.0731842	total: 4.3s	remaining: 359ms
# 323:	learn: 0.0731186	total: 4.31s	remaining: 346ms
# 324:	learn: 0.0731071	total: 4.32s	remaining: 333ms
# 325:	learn: 0.0730570	total: 4.34s	remaining: 319ms
# 326:	learn: 0.0730083	total: 4.35s	remaining: 306ms
# 327:	learn: 0.0729561	total: 4.36s	remaining: 293ms
# 328:	learn: 0.0729365	total: 4.38s	remaining: 279ms
# 329:	learn: 0.0729239	total: 4.39s	remaining: 266ms
# 330:	learn: 0.0728774	total: 4.4s	remaining: 253ms
# 331:	learn: 0.0728050	total: 4.42s	remaining: 239ms
# 332:	learn: 0.0727721	total: 4.43s	remaining: 226ms
# 333:	learn: 0.0727232	total: 4.44s	remaining: 213ms
# 334:	learn: 0.0726967	total: 4.46s	remaining: 200ms
# 335:	learn: 0.0726859	total: 4.47s	remaining: 186ms
# 336:	learn: 0.0726661	total: 4.48s	remaining: 173ms
# 337:	learn: 0.0726128	total: 4.49s	remaining: 160ms
# 338:	learn: 0.0725842	total: 4.51s	remaining: 146ms
# 339:	learn: 0.0725212	total: 4.52s	remaining: 133ms
# 340:	learn: 0.0724997	total: 4.53s	remaining: 120ms
# 341:	learn: 0.0724845	total: 4.54s	remaining: 106ms
# 342:	learn: 0.0724602	total: 4.56s	remaining: 93ms
# 343:	learn: 0.0724199	total: 4.57s	remaining: 79.7ms
# 344:	learn: 0.0723767	total: 4.58s	remaining: 66.4ms
# 345:	learn: 0.0723223	total: 4.6s	remaining: 53.1ms
# 346:	learn: 0.0722568	total: 4.61s	remaining: 39.9ms
# 347:	learn: 0.0722056	total: 4.62s	remaining: 26.6ms
# 348:	learn: 0.0721735	total: 4.63s	remaining: 13.3ms
# 349:	learn: 0.0721565	total: 4.65s	remaining: 0us

# %%
print(classification_report(y_test, prediction))

print(Counter(prediction).values())
print(Counter(y_test).values())
# Out:
#               precision    recall  f1-score   support
#
#            0       0.98      1.00      0.99     43091
#            1       0.40      0.03      0.06      1048
#
#     accuracy                           0.98     44139
#    macro avg       0.69      0.52      0.52     44139
# weighted avg       0.96      0.98      0.97     44139
#
# dict_values([44055, 84])
# dict_values([43091, 1048])

# %%
from sklearn.metrics import confusion_matrix
cm = confusion_matrix(y_test, prediction)
print('Confusion matrix\n\n', cm)
print('\nTrue Positives(TP) = ', cm[0,0])
print('\nTrue Negatives(TN) = ', cm[1,1])
print('\nFalse Positives(FP) = ', cm[0,1])
print('\nFalse Negatives(FN) = ', cm[1,0])
# Out:
# Confusion matrix
#
#  [[43041    50]
#  [ 1014    34]]
#
# True Positives(TP) =  43041
#
# True Negatives(TN) =  34
#
# False Positives(FP) =  50
#
# False Negatives(FN) =  1014
